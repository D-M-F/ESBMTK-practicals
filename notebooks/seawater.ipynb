# %%
import gsw
density = gsw.rho(SA=35.0, CT=18.0, p=0.0)
density
# Out:
# np.float64(1025.1491606174166)

# %%
(62.4-7.3*7.8)*(2040/210)
# Out:
# 53.040000000000006

# %%
7.3*7.8
# Out:
# 56.94

# %%
(2040/280)*(3.60e14*3750*1025/1.77e20)
# Out:
# 56.958232445520586
