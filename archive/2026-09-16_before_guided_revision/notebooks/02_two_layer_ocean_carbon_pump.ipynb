# %% [markdown]
# # 02 — Choose a teaching copy
#
# This practical now has maskable instructor and student versions.
#
# - [Student exercise](student/02_two_layer_ocean_carbon_pump.ipynb)
# - [Instructor source and solutions](instructor/02_two_layer_ocean_carbon_pump.ipynb)
#
# Edit the instructor source, then run `python scripts/build_student_notebooks.py`.
