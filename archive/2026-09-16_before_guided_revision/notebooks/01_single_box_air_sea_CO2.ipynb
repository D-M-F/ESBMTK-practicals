# %% [markdown]
# # 01 — Choose a teaching copy
#
# This practical now has maskable instructor and student versions.
#
# - [Student exercise](student/01_single_box_air_sea_CO2.ipynb)
# - [Instructor source and solutions](instructor/01_single_box_air_sea_CO2.ipynb)
#
# Edit the instructor source, then run `python scripts/build_student_notebooks.py`.
